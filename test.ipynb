# %% [markdown]
# <a href="https://colab.research.google.com/github/ozan40/CIP_FS25_104/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 5
b = 4
c = a + b
print(c)
# Out:
# 9
